# %% [markdown]
# # KDE over time

# %%
import matplotlib.pyplot as plt
import numpy as np

from ema_workbench import ema_logging, load_results
from ema_workbench.analysis.plotting import kde_over_time

ema_logging.log_to_stderr(ema_logging.INFO)

file_name = './data/data_kde7.tar.gz' 

experiments, outcomes = load_results(file_name)
# Out:
# [MainProcess/INFO] results loaded succesfully from C:\Users\irene\EMA\data\data_kde7.tar.gz

# %%
fig, axes = kde_over_time(experiments, outcomes, log=True)
ax = fig.get_axes()
plt.xlabel('Time (2010-2100)')
fig.set_size_inches(13,13)

ax[0].set_ylabel('Gt food/Year')
ax[1].set_ylabel('GtC/Year')
ax[2].set_ylabel('GtC')
ax[3].set_ylabel('GtMF')


# ax[6].set_xticklabels(np.arange(2010, 2101, 3.5))

plt.savefig('Figures/kde7_all4.png', bbox_inches="tight")
plt.show()

# %%
# subplot


lines(experiments, outcomes,outcomes_to_show = ['Total vertical migration', 'Atmospheric C', 'Food provision by MF', 'Biomass mesopelagic fish'] , group_by = 'policy' ,density = Density.KDE)
fig = plt.gcf()
fig.set_size_inches(13,15)
ax = fig.get_axes()

ax[0].set_ylabel('Gt fish/Year')
ax[2].set_ylabel('Gt fish')
ax[4].set_ylabel('Dmnl')
ax[6].set_ylabel('GtMF')

    
sns.despine()
plt.savefig('Figures/kde_all.png',bbox_inches="tight")
plt.show()

# %%
fig, axes = kde_over_time(experiments, outcomes, outcomes_to_show='Food provision by MF', log=True)
plt.title('Kernel Density Plot Food Provision by Mesopelagic Fish')
plt.ylabel('Food provsion by Mesopelagic Fish (GtC/Year)')
plt.xlabel('Time (2010-2100)')
ax = fig.get_axes()
ax[0].set_xticklabels(np.arange(2010, 2101, 3.5))

plt.savefig('Figures/kde7_food.png')
plt.show()

# %%
fig, axes = kde_over_time(experiments, outcomes, outcomes_to_show='Atmospheric C', log=True)
plt.title('Kernel Density Plot Food Provision by Mesopelagic Fish')

plt.ylabel('Atmospheric Carbon levels (GtC)')
plt.xlabel('Time (2010-2100)')
plt.savefig('Figures/kde7_atm.png')
plt.show()

# %%
fig, axes = kde_over_time(experiments, outcomes, outcomes_to_show='Biomass mesopelagic fish', log=True)
plt.title('Kernel Density Plot Food Provision by Mesopelagic Fish')

plt.ylabel('Biomass mesopelagic fish (Gt)')
plt.xlabel('Time (2010-2100)')
plt.savefig('Figures/kde7_bio.png')
plt.show()

# %%
fig, axes = kde_over_time(experiments, outcomes, outcomes_to_show='Total vertical migration', log=True)
plt.title('Kernel Density Plot Food Provision by Mesopelagic Fish')

plt.ylabel('Total vertical migration (GtC/Year)')
plt.xlabel('Time (2010-2100)')
plt.savefig('Figures/kde7_vm.png')
plt.show()
